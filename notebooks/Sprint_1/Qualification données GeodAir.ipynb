# %% [markdown]
# # Scripts de Qualification des données Geod'Air

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %% [markdown]
# ## Functions

# %%
# lire les données d'un poluant à partir des fichiers csv de 2013 jusqu'au 2023
def LoadData(path):
    files = os.listdir(path)
    data = pd.DataFrame()
    for file in files : 
        file_df = pd.read_csv(path+ file, sep=';')
        data = pd.concat([data, file_df]).reset_index(drop=True)
    return data

# retourner les données d'un polluant pour une organisme donnée
def data_org(data, organisme):
    data_organisme = data[data['Organisme']==organisme]
    return data_organisme

# retourner te taux des données manquantes pour un polluant sur une periode 
def proportion_jours_manquants(data_organisme):
    date_début = data_organisme.index[0]
    date_fin = data_organisme.index[-1]
    jours_manquants = pd.date_range(start = date_début, end = date_fin).difference(data_organisme.index)
    proportion = len(jours_manquants)/len(data_organisme)
    print("***")
    print(f" L'organisme {data_organisme['Organisme'].unique()[0]} a prix les mesures du {date_début} jusqu'au {date_fin}")
    print(f" Entre ces deux dates {len(jours_manquants)} jours manquent soit un taux de  {proportion: .4f}")

    return jours_manquants, proportion, date_début, date_fin

# %%
# lire les données du polluant PM25
Data = LoadData('./PM25/')

# %%
Data.head()
# Out:
#          Date de début          Date de fin       Organisme code zas  \
# 0  2013/01/01 00:00:00  2013/01/01 23:59:59  ATMO GRAND EST  FR01A01
# 1  2013/01/01 00:00:00  2013/01/01 23:59:59  ATMO GRAND EST  FR01A01
# 2  2013/01/01 00:00:00  2013/01/01 23:59:59        ATMO SUD  FR02N30
# 3  2013/01/01 00:00:00  2013/01/01 23:59:59        ATMO SUD  FR03A02
# 4  2013/01/01 00:00:00  2013/01/01 23:59:59        ATMO SUD  FR03A02
#
#                                     Zas code site              nom site  \
# 0                         LORRAINE-METZ   FR01011           Metz-Centre
# 1                         LORRAINE-METZ   FR01020     Thionville-Centre
# 2         PROVENCE-ALPES-COTE-D-AZUR-ZI   FR02020      Rognac les Brets
# 3  PROVENCE-ALPES-COTE-D-AZUR-MARSEILLE   FR03006     MARSEILLE RABATAU
# 4  PROVENCE-ALPES-COTE-D-AZUR-MARSEILLE   FR03029  AIX CENTRE ECOLE ART
#
#   type d'implantation Polluant type d'influence  ... valeur valeur brute  \
# 0             Urbaine    PM2.5             Fond  ...   13.0    12.675000
# 1             Urbaine    PM2.5             Fond  ...    6.1     6.125000
# 2         Périurbaine    PM2.5             Fond  ...   14.0    13.654167
# 3             Urbaine    PM2.5           Trafic  ...   17.0    16.650000
# 4             Urbaine    PM2.5             Fond  ...   22.0    22.254167
#
#   unité de mesure  taux de saisie  couverture temporelle  \
# 0           µg-m3           100.0                    100
# 1           µg-m3           100.0                    100
# 2           µg-m3           100.0                    100
# 3           µg-m3           100.0                    100
# 4           µg-m3           100.0                    100
#
#   couverture de données  code qualité  validité   Latitude Longitude
# 0                 100.0             A         1  49.119442  6.180833
# 1                 100.0             A         1  49.358337  6.156942
# 2                 100.0             R         1  43.510802  5.220046
# 3                 100.0             A         1  43.276451  5.397360
# 4                 100.0             A         1  43.530285  5.440912
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Exctraction d'information

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 603703 entries, 0 to 603702
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Date de début          603703 non-null  object
#  1   Date de fin            603703 non-null  object
#  2   Organisme              603703 non-null  object
#  3   code zas               603703 non-null  object
#  4   Zas                    603703 non-null  object
#  5   code site              603703 non-null  object
#  6   nom site               603703 non-null  object
#  7   type d'implantation    603703 non-null  object
#  8   Polluant               603703 non-null  object
#  9   type d'influence       603703 non-null  object
#  10  Réglementaire          603703 non-null  object
#  11  type d'évaluation      603703 non-null  object
#  12  type de valeur         603703 non-null  object
#  13  valeur                 603703 non-null  float64
#  14  valeur brute           603703 non-null  float64
#  15  unité de mesure        603703 non-null  object
#  16  taux de saisie         603703 non-null  float64
#  17  couverture temporelle  603703 non-null  int64
#  18  couverture de données  603703 non-null  float64
#  19  code qualité           603703 non-null  object
#  20  validité               603703 non-null  int64
#  21  Latitude               603703 non-null  float64
#  22  Longitude              603703 non-null  float64
# dtypes: float64(6), int64(2), object(15)
# memory usage: 105.9+ MB

# %%
Data.describe()
# Out:
#               valeur   valeur brute  taux de saisie  couverture temporelle  \
# count  603703.000000  603703.000000   603703.000000          603703.000000
# mean       14.584705      14.585179       94.430520              99.999861
# std       153.585409     153.584913       19.719171               0.082991
# min        -2.000000      -1.981818        0.000000              38.000000
# 25%         5.100000       5.141667      100.000000             100.000000
# 50%         8.200000       8.183333      100.000000             100.000000
# 75%        13.000000      13.145833      100.000000             100.000000
# max     10000.000000    9999.900000      100.000000             100.000000
#
#        couverture de données       validité       Latitude      Longitude
# count          603703.000000  603703.000000  603703.000000  603703.000000
# mean               94.430520       0.877519      44.312516       2.744882
# std                19.719171       0.479542      12.034001      13.218469
# min                 0.000000      -1.000000     -21.342915     -63.081481
# 25%               100.000000       1.000000      44.548647       0.758833
# 50%               100.000000       1.000000      46.942941       3.084158
# 75%               100.000000       1.000000      48.838615       5.360119
# max               100.000000       1.000000      51.048580      55.627930

# %%
Data['Date de début'] = pd.to_datetime(Data['Date de début'])
Data['Date de fin'] = pd.to_datetime(Data['Date de fin'])

# %%
Data
# Out:
#        Date de début         Date de fin       Organisme   code zas  \
# 0         2013-01-01 2013-01-01 23:59:59  ATMO GRAND EST    FR01A01
# 1         2013-01-01 2013-01-01 23:59:59  ATMO GRAND EST    FR01A01
# 2         2013-01-01 2013-01-01 23:59:59        ATMO SUD    FR02N30
# 3         2013-01-01 2013-01-01 23:59:59        ATMO SUD    FR03A02
# 4         2013-01-01 2013-01-01 23:59:59        ATMO SUD    FR03A02
# ...              ...                 ...             ...        ...
# 603698    2023-05-09 2023-05-09 23:59:59    ATMO REUNION  FR04ZAR02
# 603699    2023-05-09 2023-05-09 23:59:59    ATMO REUNION  FR04ZAR01
# 603700    2023-05-09 2023-05-09 23:59:59    ATMO REUNION  FR04ZAR02
# 603701    2023-05-09 2023-05-09 23:59:59    ATMO REUNION  FR04ZRE01
# 603702    2023-05-09 2023-05-09 23:59:59    HAWA MAYOTTE  FR06ZRE01
#
#                                          Zas code site              nom site  \
# 0                              LORRAINE-METZ   FR01011           Metz-Centre
# 1                              LORRAINE-METZ   FR01020     Thionville-Centre
# 2              PROVENCE-ALPES-COTE-D-AZUR-ZI   FR02020      Rognac les Brets
# 3       PROVENCE-ALPES-COTE-D-AZUR-MARSEILLE   FR03006     MARSEILLE RABATAU
# 4       PROVENCE-ALPES-COTE-D-AZUR-MARSEILLE   FR03029  AIX CENTRE ECOLE ART
# ...                                      ...       ...                   ...
# 603698                            ZAR VOLCAN   FR38017           Grand Coude
# 603699                       ZAR SAINT-DENIS   FR38020       Plateau Caillou
# 603700                            ZAR VOLCAN   FR38023              BD BANKS
# 603701                         ZR LA REUNION   FR38024         RDT SAINT-LEU
# 603702                            ZR MAYOTTE   FR43099           Kawéni Nord
#
#            type d'implantation Polluant type d'influence  ... valeur  \
# 0                      Urbaine    PM2.5             Fond  ...   13.0
# 1                      Urbaine    PM2.5             Fond  ...    6.1
# 2                  Périurbaine    PM2.5             Fond  ...   14.0
# 3                      Urbaine    PM2.5           Trafic  ...   17.0
# 4                      Urbaine    PM2.5             Fond  ...   22.0
# ...                        ...      ...              ...  ...    ...
# 603698        Rurale régionale    PM2.5             Fond  ...    4.3
# 603699                 Urbaine    PM2.5             Fond  ...    3.2
# 603700                 Urbaine    PM2.5           Trafic  ...    0.0
# 603701  Rurale près des villes    PM2.5           Trafic  ...    4.0
# 603702             Périurbaine    PM2.5           Trafic  ...   17.0
#
#        valeur brute unité de mesure  taux de saisie  couverture temporelle  \
# 0         12.675000           µg-m3           100.0                    100
# 1          6.125000           µg-m3           100.0                    100
# 2         13.654167           µg-m3           100.0                    100
# 3         16.650000           µg-m3           100.0                    100
# 4         22.254167           µg-m3           100.0                    100
# ...             ...             ...             ...                    ...
# 603698     4.291304           µg-m3            96.0                    100
# 603699     3.152174           µg-m3            96.0                    100
# 603700     0.000000           µg-m3             0.0                    100
# 603701     4.037500           µg-m3           100.0                    100
# 603702    16.837500           µg-m3           100.0                    100
#
#        couverture de données  code qualité  validité   Latitude  Longitude
# 0                      100.0             A         1  49.119442   6.180833
# 1                      100.0             A         1  49.358337   6.156942
# 2                      100.0             R         1  43.510802   5.220046
# 3                      100.0             A         1  43.276451   5.397360
# 4                      100.0             A         1  43.530285   5.440912
# ...                      ...           ...       ...        ...        ...
# 603698                  96.0             A         1 -21.294330  55.627930
# 603699                  96.0             A         1 -21.009739  55.272675
# 603700                   0.0             N        -1 -21.331703  55.478949
# 603701                 100.0             A         1 -21.213212  55.302844
# 603702                 100.0             A         1 -12.761174  45.226197
#
# [603703 rows x 23 columns]

# %% [markdown]
# ## Profondeur Historique

# %%
Data['Date de début'].min()
# Out:
# Timestamp('2013-01-01 00:00:00')

# %% [markdown]
# ## Granularité Temporelle
# La granularité temporelle des données du polluant PM25 est de l'ordre d'1 jour.

# %%
(Data['Date de début'] - Data['Date de fin']).min(), (Data['Date de début'] - Data['Date de fin']).max()
# Out:
# (Timedelta('-1 days +00:00:01'), Timedelta('-1 days +06:00:00'))

# %% [markdown]
# ## Couverture Géographique, Granularité spatiale, Régions
# Les données du polluant PM25 sont prises sur les 18 régions de la France métropolitaine et outre mer.

# %%
# France métropolitaine et outre mer, 18 régions 
Data.Zas.unique()
# Out:
# array(['LORRAINE-METZ', 'PROVENCE-ALPES-COTE-D-AZUR-ZI',
#        'PROVENCE-ALPES-COTE-D-AZUR-MARSEILLE',
#        'PROVENCE-ALPES-COTE-D-AZUR-TOULON',
#        'PROVENCE-ALPES-COTE-D-AZUR-AVIGNON', 'ILE-DE-FRANCE-PARIS',
#        'ILE-DE-FRANCE-ZR', 'HAUTE-NORMANDIE-ZI', 'HAUTE-NORMANDIE-ZR',
#        'NORD-PAS-DE-CALAIS-DOUAI-BETHUNE-VALENCIENNES',
#        'NORD-PAS-DE-CALAIS-ZR', 'AUVERGNE-CLERMONT',
#        'LANGUEDOC-ROUSSILLON-MONTPELLIER', 'LANGUEDOC-ROUSSILLON-ZUR',
#        'POITOU-CHARENTES-ZUR', 'NORD-PAS-DE-CALAIS-ZUR',
#        'NORD-PAS-DE-CALAIS-LILLE', 'MIDI-PYRENEES-ZR',
#        'MIDI-PYRENEES-TOULOUSE', 'CHAMPAGNE-ARDENNE-ZR',
#        'CHAMPAGNE-ARDENNE-ZUR', 'RHONE-ALPES-GRENOBLE',
#        'ALSACE-STRASBOURG', 'ALSACE-MULHOUSE', 'PICARDIE-ZUR',
#        'BRETAGNE-RENNES', 'BRETAGNE-ZR', 'BRETAGNE-ZUR',
#        'RHONE-ALPES-LYON', 'BASSE-NORMANDIE-ZUR', 'BASSE-NORMANDIE-ZR',
#        'PAYS DE LA LOIRE-NANTES', 'PAYS DE LA LOIRE-ZUR',
#        'PAYS DE LA LOIRE-ZR', 'PROVENCE-ALPES-COTE-D-AZUR-NICE',
#        'HAUTE-NORMANDIE-ROUEN', 'BOURGOGNE-ZUR', 'RHONE-ALPES-ST-ETIENNE',
#        'LORRAINE-ZR', 'LORRAINE-NANCY', 'AQUITAINE-BORDEAUX',
#        'AQUITAINE-ZUR', 'RHONE-ALPES-ZUR', 'CENTRE-ORLEANS',
#        'CENTRE-TOURS', 'CENTRE-ZR', 'CENTRE-ZUR', 'LIMOUSIN-ZUR',
#        'RHONE-ALPES-ZR', 'REUNION-ZUR', 'REUNION-ZR', 'MARTINIQUE-ZUR',
#        'GUYANE-ZUR', 'CORSE-ZUR', 'FRANCHE-COMTE-ZUR', 'FRANCHE-COMTE-ZR',
#        'PICARDIE-ZR', 'CORSE-ZR', 'HAUTE-NORMANDIE-ZUR', 'AUVERGNE-ZR',
#        'LANGUEDOC-ROUSSILLON-ZR', 'PROVENCE-ALPES-COTE-D-AZUR-ZR',
#        'BOURGOGNE-ZR', 'AQUITAINE-ZR', 'LIMOUSIN-ZR',
#        'PROVENCE-ALPES-COTE-D-AZUR-ZUR', 'ZAR SAINT-DENIS', 'ZAR VOLCAN',
#        'ZAG METZ', 'ZR GRAND-EST', 'ZAG MARSEILLE-AIX',
#        'ZAR FREJUS-DRAGUIGNAN', 'ZAG TOULON', 'ZAG AVIGNON', 'ZAG PARIS',
#        'ZR ILE-DE-FRANCE', 'ZR NORMANDIE', 'ZAR LE-HAVRE', 'ZAG BLDV',
#        'ZR HAUTS-DE-FRANCE', 'ZAG CLERMONT-FERRAND',
#        'ZR AUVERGNE-RHONE-ALPES', 'ZAG MONTPELLIER', 'ZR OCCITANIE',
#        'ZAR NIMES', 'ZAR PERPIGNAN', 'ZR NOUVELLE-AQUITAINE', 'ZAR NIORT',
#        'ZAR POITIERS', 'ZAR COTE-D-OPALE', 'ZAG LILLE', 'ZAG TOULOUSE',
#        'ZAR REIMS', 'ZAG GRENOBLE', 'ZAG STRASBOURG', 'ZAR CREIL',
#        'ZAG RENNES', 'ZR BRETAGNE', 'ZAR BREST', 'ZAG LYON', 'ZAR CAEN',
#        'ZAG NANTES-SAINT-NAZAIRE', 'ZAR ANGERS-LOIRE',
#        'ZR PAYS-DE-LA-LOIRE', 'ZAR LE-MANS',
#        'ZR PROVENCE-ALPES-COTE D’AZUR', 'ZAG NICE', 'ZAG ROUEN',
#        'ZAR DIEPPE', 'ZAR DIJON', 'ZR BOURGOGNE-FRANCHE-COMTE',
#        'ZAR VALLEE-DU-RHONE', 'ZAG SAINT-ETIENNE', 'ZAG NANCY',
#        'ZAG BORDEAUX', 'ZAR CHALON', 'ZAR PAYS-DE-SAVOIE',
#        'ZAR VALLEE-DE-L-ARVE', 'ZAG ORLEANS', 'ZAG TOURS',
#        'ZR CENTRE-VAL DE LOIRE', 'ZAR CHARTRES-DREUX', 'ZAR LIMOGES',
#        'ZAR FORT-DE-FRANCE', 'ZAR BASTIA', 'ZR CORSE', 'ZAR BESANCON',
#        'ZAR BELFORT-MONTBELIARD', 'ZAR AMIENS', 'ZR MARTINIQUE',
#        'ZAG POINTE-A-PITRE', 'ZAR VALLEE-DE-LA-TARANTAISE',
#        'ZR LA REUNION', 'ZAR ILE-DE-CAYENNE', 'ZAR AJACCIO',
#        'ZAR MOULINS', 'ZAR BLOIS', 'ZR PROVENCE-ALPES-COTE D?AZUR',
#        'ZR PROVENCE-ALPES-COTE-D-AZUR', 'ZAG BAYONNE',
#        'ZR CENTRE-VAL-DE-LOIRE', 'ZR GUADELOUPE', 'ZR GUYANE',
#        'ZR MAYOTTE'], dtype=object)

# %% [markdown]
# ## Présence des coordonnées GPS des stations

# %%
Data[['Latitude', 'Longitude']]
# Out:
#          Latitude  Longitude
# 0       49.119442   6.180833
# 1       49.358337   6.156942
# 2       43.510802   5.220046
# 3       43.276451   5.397360
# 4       43.530285   5.440912
# ...           ...        ...
# 603698 -21.294330  55.627930
# 603699 -21.009739  55.272675
# 603700 -21.331703  55.478949
# 603701 -21.213212  55.302844
# 603702 -12.761174  45.226197
#
# [603703 rows x 2 columns]

# %% [markdown]
# ## Indicateur sur la typologie des stations
# Il y a 3 typologie des stations : Fond, Trafic et Indutrielle

# %%
Data["type d'influence"].unique()
# Out:
# array(['Fond', 'Trafic', 'Industrielle'], dtype=object)

# %% [markdown]
# ## Type d'implantation
# Il y a 5 types d'implantations : Urbaine, Périuraine, Rurale régionale, Rurale nationale et Rurale près des villes

# %%
Data["type d'implantation"].unique()
# Out:
# array(['Urbaine', 'Périurbaine', 'Rurale régionale', 'Rurale nationale',
#        'Rurale près des villes'], dtype=object)

# %% [markdown]
# ## Taux de données manquantes

# %%
Data.isnull().sum()
# Out:
# Date de début            0
# Date de fin              0
# Organisme                0
# code zas                 0
# Zas                      0
# code site                0
# nom site                 0
# type d'implantation      0
# Polluant                 0
# type d'influence         0
# Réglementaire            0
# type d'évaluation        0
# type de valeur           0
# valeur                   0
# valeur brute             0
# unité de mesure          0
# taux de saisie           0
# couverture temporelle    0
# couverture de données    0
# code qualité             0
# validité                 0
# Latitude                 0
# Longitude                0
# dtype: int64

# %% [markdown]
# ## Présence d’indicateurs sur la qualité des mesures
# ### Taux de saisie

# %%
Data['taux de saisie'].mean()
# Out:
# 94.43051964293701

# %% [markdown]
#  ### Code Qualité de mesure :

# %%
Data['code qualité'].value_counts()/len(Data['code qualité'])*100
# Out:
# A    81.599727
# R    12.276235
# N     6.124038
# Name: code qualité, dtype: float64

# %% [markdown]
# ### Validité

# %%
Data['validité'].value_counts()/len(Data['validité'])*100
# Out:
#  1    93.875962
# -1     6.124038
# Name: validité, dtype: float64

# %% [markdown]
# ### Valeurs manquantes par Région

# %%
Data.set_index('Date de début', inplace=True)
Data.head()
# Out:
#                       Date de fin       Organisme code zas  \
# Date de début
# 2013-01-01    2013-01-01 23:59:59  ATMO GRAND EST  FR01A01
# 2013-01-01    2013-01-01 23:59:59  ATMO GRAND EST  FR01A01
# 2013-01-01    2013-01-01 23:59:59        ATMO SUD  FR02N30
# 2013-01-01    2013-01-01 23:59:59        ATMO SUD  FR03A02
# 2013-01-01    2013-01-01 23:59:59        ATMO SUD  FR03A02
#
#                                                 Zas code site  \
# Date de début
# 2013-01-01                            LORRAINE-METZ   FR01011
# 2013-01-01                            LORRAINE-METZ   FR01020
# 2013-01-01            PROVENCE-ALPES-COTE-D-AZUR-ZI   FR02020
# 2013-01-01     PROVENCE-ALPES-COTE-D-AZUR-MARSEILLE   FR03006
# 2013-01-01     PROVENCE-ALPES-COTE-D-AZUR-MARSEILLE   FR03029
#
#                            nom site type d'implantation Polluant  \
# Date de début
# 2013-01-01              Metz-Centre             Urbaine    PM2.5
# 2013-01-01        Thionville-Centre             Urbaine    PM2.5
# 2013-01-01         Rognac les Brets         Périurbaine    PM2.5
# 2013-01-01        MARSEILLE RABATAU             Urbaine    PM2.5
# 2013-01-01     AIX CENTRE ECOLE ART             Urbaine    PM2.5
#
#               type d'influence Réglementaire  ... valeur valeur brute  \
# Date de début                                 ...
# 2013-01-01                Fond           Oui  ...   13.0    12.675000
# 2013-01-01                Fond           Oui  ...    6.1     6.125000
# 2013-01-01                Fond           Oui  ...   14.0    13.654167
# 2013-01-01              Trafic           Oui  ...   17.0    16.650000
# 2013-01-01                Fond           Oui  ...   22.0    22.254167
#
#                unité de mesure  taux de saisie couverture temporelle  \
# Date de début
# 2013-01-01               µg-m3           100.0                   100
# 2013-01-01               µg-m3           100.0                   100
# 2013-01-01               µg-m3           100.0                   100
# 2013-01-01               µg-m3           100.0                   100
# 2013-01-01               µg-m3           100.0                   100
#
#                couverture de données  code qualité  validité   Latitude  \
# Date de début
# 2013-01-01                     100.0             A         1  49.119442
# 2013-01-01                     100.0             A         1  49.358337
# 2013-01-01                     100.0             R         1  43.510802
# 2013-01-01                     100.0             A         1  43.276451
# 2013-01-01                     100.0             A         1  43.530285
#
#                Longitude
# Date de début
# 2013-01-01      6.180833
# 2013-01-01      6.156942
# 2013-01-01      5.220046
# 2013-01-01      5.397360
# 2013-01-01      5.440912
#
# [5 rows x 22 columns]

# %%
for org_val in Data['Organisme'].unique():
    data_organisme = data_org(Data, org_val)
    jours_manquants, proportion, date_début, date_fin = proportion_jours_manquants(data_organisme)
# Out:
# ***
#  L'organisme ATMO GRAND EST a prix les mesures du 2013-01-01 00:00:00 jusqu'au 2023-05-09 00:00:00
#  Entre ces deux dates 0 jours manquent soit un taux de   0.0000
# ***
#  L'organisme ATMO SUD a prix les mesures du 2013-01-01 00:00:00 jusqu'au 2023-05-09 00:00:00
#  Entre ces deux dates 0 jours manquent soit un taux de   0.0000
# ***
#  L'organisme AIRPARIF a prix les mesures du 2013-01-01 00:00:00 jusqu'au 2023-05-09 00:00:00
#  Entre ces deux dates 0 jours manquent soit un taux de   0.0000
# ***
#  L'organisme ATMO NORMANDIE a prix les mesures du 2013-01-01 00:00:00 jusqu'au 2023-05-09 00:00:00
#  Entre ces deux dates 0 jours manquent soit un taux de   0.0000
# ***
#  L'organisme ATMO HAUTS DE FRANCE a prix les mesures du 2013-01-01 00:00:00 jusqu'au 2023-05-09 00:00:00
#  Entre ces deux dates 0 jours manquent soit un taux de   0.0000
# ***
#  L'organisme ATMO AUVERGNE-RHÔNE-ALPES a prix les mesures du 2013-01-01 00:00:00 jusqu'au 2023-05-09 00:00:00
#  Entre ces deux dates 0 jours manquent soit un taux de   0.0000
# ***
#  L'organisme ATMO OCCITANIE a prix les mesures du 2013-01-01 00:00:00 jusqu'au 2023-05-09 00:00:00
#  Entre ces deux dates 0 jours manquent soit un taux de   0.0000
# ***
#  L'organisme ATMO NOUVELLE-AQUITAINE a prix les mesures du 2013-01-01 00:00:00 jusqu'au 2023-05-09 00:00:00
#  Entre ces deux dates 0 jours manquent soit un taux de   0.0000
# ***
#  L'organisme AIR BREIZH a prix les mesures du 2013-01-01 00:00:00 jusqu'au 2023-05-09 00:00:00
#  Entre ces deux dates 0 jours manquent soit un taux de   0.0000
# ***
#  L'organisme AIR PAYS DE LA LOIRE a prix les mesures du 2013-01-01 00:00:00 jusqu'au 2023-05-09 00:00:00
#  Entre ces deux dates 0 jours manquent soit un taux de   0.0000
# ***
#  L'organisme ATMO BOURGOGNE-FRANCHE-COMTE a prix les mesures du 2013-01-01 00:00:00 jusqu'au 2023-05-09 00:00:00
#  Entre ces deux dates 0 jours manquent soit un taux de   0.0000
# ***
#  L'organisme LIG'AIR a prix les mesures du 2013-01-01 00:00:00 jusqu'au 2023-05-09 00:00:00
#  Entre ces deux dates 0 jours manquent soit un taux de   0.0000
# ***
#  L'organisme ATMO REUNION a prix les mesures du 2013-01-01 00:00:00 jusqu'au 2023-05-09 00:00:00
#  Entre ces deux dates 7 jours manquent soit un taux de   0.0005
# ***
#  L'organisme MADININAIR a prix les mesures du 2013-01-01 00:00:00 jusqu'au 2023-05-09 00:00:00
#  Entre ces deux dates 52 jours manquent soit un taux de   0.0056
# ***
#  L'organisme ATMO GUYANE a prix les mesures du 2013-01-01 00:00:00 jusqu'au 2023-05-09 00:00:00
#  Entre ces deux dates 1029 jours manquent soit un taux de   0.3174
# ***
#  L'organisme QUALITAIR CORSE a prix les mesures du 2013-01-01 00:00:00 jusqu'au 2023-05-09 00:00:00
#  Entre ces deux dates 0 jours manquent soit un taux de   0.0000
# ***
#  L'organisme GWAD'AIR a prix les mesures du 2018-01-16 00:00:00 jusqu'au 2023-05-09 00:00:00
#  Entre ces deux dates 59 jours manquent soit un taux de   0.0217
# ***
#  L'organisme HAWA MAYOTTE a prix les mesures du 2022-01-01 00:00:00 jusqu'au 2023-05-09 00:00:00
#  Entre ces deux dates 2 jours manquent soit un taux de   0.0041
